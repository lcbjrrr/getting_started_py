# %% [markdown]
# Create a base class Animal with a method sound() and create derived classes Dog and Cat with their own sound().

# %%
import csv
import json

# 1. Create a base class Animal with a method sound() and create derived classes Dog and Cat with their own sound().
class Animal:
    def __init__(self, name):
        self.name = name

    def sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def sound(self):
        print("Woof!")

class Cat(Animal):
    def sound(self):
        print("Meow!")

# Example Usage:
animal = Animal("Generic Animal")
animal.sound()  # Output: Generic animal sound

dog = Dog("Buddy")
dog.sound()     # Output: Woof!

cat = Cat("Whiskers")
cat.sound()   # Output: Meow!

# %% [markdown]
# Implement a class hierarchy to represent different types of vehicles (Car, Bike) with their own attributes and methods.

# %%
# 2. Implement a class hierarchy to represent different types of vehicles (Car, Bike) with their own attributes and methods.
class Vehicle:
    def __init__(self, model, year):
        self.model = model
        self.year = year

    def start_engine(self):
        print("Engine started")

class Car(Vehicle):
    def __init__(self, model, year, num_doors):
        super().__init__(model, year)
        self.num_doors = num_doors

    def drive(self):
        print("Driving car")

class Bike(Vehicle):
    def __init__(self, model, year, has_basket):
        super().__init__(model, year)
        self.has_basket = has_basket

    def ride(self):
        print("Riding bike")

# Example Usage:
car = Car("Sedan", 2020, 4)
car.start_engine()  # Output: Engine started
car.drive()         # Output: Driving car

bike = Bike("Mountain Bike", 2021, True)
bike.start_engine() # Output: Engine started
bike.ride()        # Output: Riding bike

# %% [markdown]
# Create a class Person with private attributes and define methods to get and set the values of those attributes.

# %%
# 3. Create a class Person with private attributes and define methods to get and set the values of those attributes.
class Person:
    def __init__(self, name, age, address):
        self.__name = name
        self.__age = age
        self.__address = address

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Invalid age")

    def get_address(self):
        return self.__address

    def set_address(self, address):
        self.__address = address

# Example Usage:
person = Person("Alice", 30, "123 Main St")
print(person.get_name())    # Output: Alice
person.set_age(31)
print(person.get_age())    # Output: 31
person.set_address("456 Oak Ave")
print(person.get_address()) # Output: 456 Oak Ave

# %% [markdown]
# Create a base class Shape with methods to calculate area and perimeter, and derive classes Circle and Square.

# %%
# 4. Create a base class Shape with methods to calculate area and perimeter, and derive classes Circle and Square.
import math

class Shape:
    def area(self):
        pass

    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

    def perimeter(self):
        return 2 * math.pi * self.radius

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side**2

    def perimeter(self):
        return 4 * self.side

# Example Usage:
circle = Circle(5)
print(f"Circle Area: {circle.area()}")       # Output: Circle Area: 78.53981633974483
print(f"Circle Perimeter: {circle.perimeter()}") # Output: Circle Perimeter: 31.41592653589793

square = Square(4)
print(f"Square Area: {square.area()}")       # Output: Square Area: 16
print(f"Square Perimeter: {square.perimeter()}") # Output: Square Perimeter: 16

# %% [markdown]
# Implement a class hierarchy to represent different types of employees (Manager, Engineer) with their attributes.

# %%
# 5. Implement a class hierarchy to represent different types of employees (Manager, Engineer) with their attributes.
class Employee:
    def __init__(self, name, employee_id, salary):
        self.name = name
        self.employee_id = employee_id
        self.salary = salary

    def get_salary(self):
        return self.salary

class Manager(Employee):
    def __init__(self, name, employee_id, salary, bonus):
        super().__init__(name, employee_id, salary)
        self.bonus = bonus

    def get_salary(self):
        return super().get_salary() + self.bonus

class Engineer(Employee):
    def __init__(self, name, employee_id, salary, specialization):
        super().__init__(name, employee_id, salary)
        self.specialization = specialization

    def get_specialization(self):
        return self.specialization

# Example Usage:
manager = Manager("John Doe", "101", 60000, 10000)
print(f"{manager.name}'s salary: ${manager.get_salary()}") # Output: John Doe's salary: $70000

engineer = Engineer("Jane Smith", "102", 50000, "Software")
print(f"{engineer.name}'s salary: ${engineer.get_salary()}, Specialization: {engineer.get_specialization()}")
# Output: Jane Smith's salary: $50000, Specialization: Software

# %% [markdown]
# Write a Python program that uses inheritance to represent a hierarchy of shapes (Triangle, Rectangle, etc.).

# %%
# 6. Write a Python program that uses inheritance to represent a hierarchy of shapes (Triangle, Rectangle, etc.).
class Shape:
    def area(self):
        pass

    def perimeter(self):
        pass

class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3):
        self.base = base
        self.height = height
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    def area(self):
        return 0.5 * self.base * self.height

    def perimeter(self):
        return self.side1 + self.side2 + self.side3

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# Example Usage:
triangle = Triangle(10, 5, 10, 12, 8)
print(f"Triangle Area: {triangle.area()}")       # Output: Triangle Area: 25.0
print(f"Triangle Perimeter: {triangle.perimeter()}") # Output: Triangle Perimeter: 30

rectangle = Rectangle(10, 5)
print(f"Rectangle Area: {rectangle.area()}")       # Output: Rectangle Area: 50
print(f"Rectangle Perimeter: {rectangle.perimeter()}") # Output: Rectangle Perimeter: 30

# %% [markdown]
# Create a class hierarchy to represent different types of animals (Bird, Fish) with their own attributes and methods.

# %%
# 7. Create a class hierarchy to represent different types of animals (Bird, Fish) with their own attributes and methods.
class Animal:
    def __init__(self, name, habitat):
        self.name = name
        self.habitat = habitat

    def move(self):
        print("Moving")

class Bird(Animal):
    def __init__(self, name, habitat, wingspan):
        super().__init__(name, habitat)
        self.wingspan = wingspan

    def fly(self):
        print("Flying")

    def move(self):
        print("Flying")  # Override move method

class Fish(Animal):
    def __init__(self, name, habitat, water_type):
        super().__init__(name, habitat)
        self.water_type = water_type

    def swim(self):
        print("Swimming")

    def move(self):
        print("Swimming")  # Override move method

# Example Usage:
bird = Bird("Eagle", "Forest", "2m")
bird.move() # Output: Flying
bird.fly()  # Output: Flying

fish = Fish("Salmon", "River", "Freshwater")
fish.move() # Output: Swimming
fish.swim() # Output: Swimming

# %% [markdown]
# Given a JSON file with product details, create a Product class with encapsulated attributes.

# %%
# 8. Given a JSON file with product details, create a Product class with encapsulated attributes.
class Product:
    def __init__(self, product_id, name, __price, __quantity):
        self.product_id = product_id
        self.name = name
        self.__price = __price
        self.__quantity = __quantity

    def get_price(self):
        return self.__price

    def set_price(self, price):
        if price > 0:
            self.__price = price
        else:
            print("Invalid price")

    def get_quantity(self):
        return self.__quantity

    def set_quantity(self, quantity):
        if quantity >= 0:
            self.__quantity = quantity
        else:
            print("Invalid quantity")

    def calculate_value(self):
        return self.__price * self.__quantity

def create_product_from_json(json_file):
    try:
        with open(json_file, 'r') as file:
            data = json.load(file)
            return Product(data['product_id'], data['name'], data['price'], data['quantity'])
    except FileNotFoundError:
        print(f"Error: File '{json_file}' not found.")
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
    return None

# Example Usage:
product = create_product_from_json('product_data.json')
if product:
    print(f"Product: {product.name}, Value: ${product.calculate_value()}")
    product.set_price(25.0)
    product.set_quantity(100)
    print(f"Updated Value: ${product.calculate_value()}")

# %% [markdown]
# Implement a program that uses inheritance to represent a hierarchy of vehicles (Car, Bike, Truck, etc.).

# %%
# 9. Implement a program that uses inheritance to represent a hierarchy of vehicles (Car, Bike, Truck, etc.).
class Vehicle:
    def __init__(self, model, year):
        self.model = model
        self.year = year

    def start_engine(self):
        print("Engine started")

class Car(Vehicle):
    def __init__(self, model, year, num_doors, fuel_type):
        super().__init__(model, year)
        self.num_doors = num_doors
        self.fuel_type = fuel_type

    def drive(self):
        print("Driving car")

class Bike(Vehicle):
    def __init__(self, model, year, bike_type):
        super().__init__(model, year)
        self.bike_type = bike_type

    def ride(self):
        print("Riding bike")

class Truck(Vehicle):
    def __init__(self, model, year, load_capacity):
        super().__init__(model, year)
        self.load_capacity = load_capacity

    def haul(self):
        print("Hauling load")

# Example Usage:
car = Car("Sedan", 2020, 4, "Gasoline")
car.start_engine()
car.drive()

bike = Bike("Mountain Bike", 2021, "Off-road")
bike.start_engine()
bike.ride()

truck = Truck("Semi-truck", 2019, "10 tons")
truck.start_engine()
truck.haul()

# %% [markdown]
# Write a Python program that uses encapsulation to protect sensitive information in a User class.

# %%
# 10. Write a Python program that uses encapsulation to protect sensitive information in a User class.
class User:
    def __init__(self, user_id, username, __password, __email):
        self.user_id = user_id
        self.username = username
        self.__password = __password  # Private attribute
        self.__email = __email      # Private attribute

    def get_email(self):
        return self.__email

    def set_email(self, email):
        if "@" in email:
            self.__email = email
        else:
            print("Invalid email format")

    def verify_password(self, password):
        return self.__password == password

    def change_password(self, old_password, new_password):
        if self.verify_password(old_password):
            self.__password = new_password
            print("Password changed successfully")
        else:
            print("Invalid old password")

# Example Usage:
user = User(1, "johndoe", "secret123", "john@example.com")
print(user.username)
print(user.get_email())
user.set_email("john.doe@newmail.com")
print(user.verify_password("secret123"))
user.change_password("secret123", "newpass")
print(user.verify_password("newpass"))

# %% [markdown]
# Create a class hierarchy to represent different types of electronics (Phone, Laptop) with their attributes.

# %%
# 11. Create a class hierarchy to represent different types of electronics (Phone, Laptop) with their attributes.
class Electronics:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def turn_on(self):
        print("Turning on")

    def turn_off(self):
        print("Turning off")

class Phone(Electronics):
    def __init__(self, brand, model, screen_size, has_5g):
        super().__init__(brand, model)
        self.screen_size = screen_size
        self.has_5g = has_5g

    def make_call(self, number):
        print(f"Calling {number}")

class Laptop(Electronics):
    def __init__(self, brand, model, cpu, ram, storage):
        super().__init__(brand, model)
        self.cpu = cpu
        self.ram = ram
        self.storage = storage

    def run_program(self, program_name):
        print(f"Running {program_name}")

# Example Usage:
phone = Phone("Samsung", "Galaxy S21", "6.2 inch", True)
phone.turn_on()
phone.make_call("123-456-7890")
phone.turn_off()

laptop = Laptop("Dell", "XPS 15", "Intel i7", "16GB", "512GB SSD")
laptop.turn_on()
laptop.run_program("VS Code")
laptop.turn_off()

# %% [markdown]
# Given a CSV file with employee details, create an Employee class with private attributes.

# %%
# 12. Given a CSV file with employee details (name, position, salary), create an Employee class with private attributes.
class Employee:
    def __init__(self, __name, __position, __salary):
        self.__name = __name
        self.__position = __position
        self.__salary = __salary

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_position(self):
        return self.__position

    def set_position(self, position):
        self.__position = position

    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if salary > 0:
            self.__salary = salary
        else:
            print("Invalid salary")

def create_employees_from_csv(csv_file):
    employees = []
    try:
        with open(csv_file, 'r') as file:
            reader = csv.DictReader(file)
            for row in reader:
                employees.append(Employee(row['name'], row['position'], float(row['salary'])))
    except FileNotFoundError:
        print(f"Error: File '{csv_file}' not found.")
    except KeyError:
        print("Error: CSV file missing required columns (name, position, salary).")
    return employees

# Example Usage:
employees = create_employees_from_csv('employee_data.csv')
for emp in employees:
    print(f"Name: {emp.get_name()}, Position: {emp.get_position()}, Salary: ${emp.get_salary()}")

# %% [markdown]
# Implement a program that uses inheritance to represent a hierarchy of shapes (Circle, Triangle, Rectangle, etc.).

# %%
# 13. Implement a program that uses inheritance to represent a hierarchy of shapes (Circle, Triangle, Rectangle, etc.).

import math

class Shape:
    def area(self):
        pass

    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

    def perimeter(self):
        return 2 * math.pi * self.radius

class Triangle(Shape):
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c

    def area(self):
        s = (self.a + self.b + self.c) / 2
        return math.sqrt(s * (s - self.a) * (s - self.b) * (s - self.c))

    def perimeter(self):
        return self.a + self.b + self.c

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height)

# Example usage
circle = Circle(5)
print(f"Circle Area: {circle.area()}")
print(f"Circle Perimeter: {circle.perimeter()}")

triangle = Triangle(3, 4, 5)
print(f"Triangle Area: {triangle.area()}")
print(f"Triangle Perimeter: {triangle.perimeter()}")

rectangle = Rectangle(4, 6)
print(f"Rectangle Area: {rectangle.area()}")
print(f"Rectangle Perimeter: {rectangle.perimeter()}")
